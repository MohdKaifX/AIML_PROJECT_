# %% [markdown]
# # Emotion Detection from scratch
#
# **Author:** MOHD KAIF <br>
# **Linkedin:** https://www.linkedin.com/in/balaji-chippada-0317/ <br>
# **Description:** Training an image classifier from scratch on the Kaggle FER-2013 Dataset.

# %% [markdown]
# # Data Set-
#
# Kaggle - https://www.kaggle.com/datasets/msambare/fer2013
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral)

# %% [markdown]
# # Setting up Kaggle Directory

# %%
import os

dataset_path = 'D:/EMOTION DETECTION/DATASET'

print(os.listdir(dataset_path))
# Out:
# ['test', 'train']

# %% [markdown]
# # Installing Packages

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import imghdr
import tensorflow as tf
from PIL import Image
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras import layers, models, regularizers, optimizers
from tensorflow.keras.applications import VGG16, ResNet50V2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard, CSVLogger
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Activation, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.utils import plot_model

# %% [markdown]
# # Setting up Directory to save model data.

# %%
os.makedirs('test_dir', exist_ok=True)

# %%
# Define your project name
project_name = 'FER_2013_Emotion_Detection'

# List your models
model_names = [
    'Custom_CNN_From_Scratch',
    'Custom_CNN_With_Augmentation',
    'VGG16_Transfer_Learning',
    'ResNet50_Transfer_Learning'
]

# Base directory (in this case, your Google Colab workspace)
base_dir = 'D:/EMOTION DETECTION'

# Create the project directory
project_dir = os.path.join(base_dir, project_name)
os.makedirs(project_dir, exist_ok=True)

# Create a subdirectory for each model
for each_model in model_names:
    model_dir = os.path.join(project_dir, each_model)
    os.makedirs(model_dir, exist_ok=True)
    # Example subdirectories for model-related files
    # os.makedirs(os.path.join(model_dir, 'checkpoints'), exist_ok=True)
    # os.makedirs(os.path.join(model_dir, 'logs'), exist_ok=True)
    # os.makedirs(os.path.join(model_dir, 'saved_models'), exist_ok=True)

print(f'Project directory structure created at: {project_dir}')
# Out:
# Project directory structure created at: D:/EMOTION DETECTION\FER_2013_Emotion_Detection

# %% [markdown]
# # Data Cleaning

# %%
# Define the list of acceptable image extensions
image_exts = ['jpeg', 'jpg', 'png']

# Path to the directory containing image classes and possibly other nested subdirectories
data_dir = 'D:/EMOTION DETECTION/DATASET/train'

# Walk through all directories and files in the dataset
for root, dirs, files in os.walk(data_dir):
    for file in files:
        # Construct the path to the current file
        file_path = os.path.join(root, file)

        try:
            # Check the file type of the current file
            file_type = imghdr.what(file_path)

            # If the file extension is not in the allowed list, remove it
            if file_type not in image_exts:
                print(f'Image not in ext list {file_path}')
                os.remove(file_path)
            else:
                # Proceed to process the image if needed, for example, reading it with OpenCV
                img = cv2.imread(file_path)

        except Exception as e:
            # Print out the issue and the path of the problematic file
            print(f'Issue with file {file_path}. Error: {e}')
            # Optionally, remove files that cause exceptions
            os.remove(file_path)

# %% [markdown]
# # Data Analysis

# %%
# Define a function to count the number of files (assumed to be images for this context) for each subdirectory in a given directory.
# The function returns a DataFrame with these counts, indexed by a specified set name (e.g., 'train' or 'test').
def count_files_in_subdirs(directory, set_name):
    # Initialize an empty dictionary to hold the count of files for each subdirectory.
    counts = {}

    # Iterate over each item in the given directory.
    for item in os.listdir(directory):
        # Construct the full path to the item.
        item_path = os.path.join(directory, item)

        # Check if the item is a directory.
        if os.path.isdir(item_path):
            # Count the number of files in the subdirectory and add it to the dictionary.
            counts[item] = len(os.listdir(item_path))

    # Convert the counts dictionary to a DataFrame for easy viewing and analysis.
    # The index of the DataFrame is set to the provided set name.
    df = pd.DataFrame(counts, index=[set_name])
    return df

# Paths to the training and testing directories.
train_dir = 'D:/EMOTION DETECTION/DATASET/train'
test_dir = 'D:/EMOTION DETECTION/DATASET/test'


# Count the files in the subdirectories of the training directory and print the result.
train_count = count_files_in_subdirs(train_dir, 'train')
print(train_count)

# Count the files in the subdirectories of the testing directory and print the result.
test_count = count_files_in_subdirs(test_dir, 'test')
print(test_count)
# Out:
#        angry  disgust  fear  happy  neutral   sad  surprise
# train   3995      436  4097   7215     4965  4830      3171
#       angry  disgust  fear  happy  neutral   sad  surprise
# test    958      111  1024   1774     1233  1247       831

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Plotting one image from each emotion.

# %%
emotions = os.listdir(train_dir)
plt.figure(figsize=(15,10))

for i, emotion in enumerate(emotions, 1):
    folder = os.path.join(train_dir, emotion)
    img_path = os.path.join(folder, os.listdir(folder)[42])
    img = plt.imread(img_path)
    plt.subplot(3, 4, i)
    plt.imshow(img, cmap='gray')
    plt.title(emotion)
    plt.axis('off')

# %% [markdown]
# # Plotting random images from given directory

# %%
def plot_images_from_directory(directory_path, class_name, num_images=9):
    # Retrieve list of all file names in the directory
    image_filenames = os.listdir(directory_path)

    # If there are fewer images than requested, we'll just show them all
    if len(image_filenames) < num_images:
        print(f"Only found {len(image_filenames)} images in {directory_path}, displaying them all.")
        num_images = len(image_filenames)

    # Randomly select 'num_images' number of file names
    selected_images = random.sample(image_filenames, num_images)

    # Plotting the images
    fig, axes = plt.subplots(3, 3, figsize=(5, 5))  # Adjust the size as needed
    axes = axes.ravel()

    for i, image_file in enumerate(selected_images):
        image_path = os.path.join(directory_path, image_file)
        # image = Image.open(image_path)
        image = load_img(image_path)
        axes[i].imshow(image)
        axes[i].set_title(f"Image: {class_name}")
        axes[i].axis('off')  # Hide the axis

    plt.tight_layout()
    plt.show()

# %%
# Placeholder for the directory path
angry_directory_path = 'D:/EMOTION DETECTION/DATASET/train/angry'  # Replace with your directory path
plot_images_from_directory(angry_directory_path, class_name = 'Angry')

# %%
# Placeholder for the directory path
disgust_directory_path = 'D:/EMOTION DETECTION/DATASET/train/disgust'  # Replace with your directory path
plot_images_from_directory(disgust_directory_path, class_name = 'Disgust')

# %%
# Placeholder for the directory path
surpirse_directory_path = '/content/train/surprise'  # Replace with your directory path
plot_images_from_directory(surpirse_directory_path, class_name = 'Surpirse')

# %% [markdown]
# # Checking shapes and channels.

# %%
image = r'D:\EMOTION DETECTION\DATASET\test\angry\PrivateTest_88305.JPG'

import cv2

img = cv2.imread(image) # Default load in color format.

# If the image is loaded successfully, print its pixel values
if img is not None:
    # print(img)
    print("Shape:", img.shape)
else:
    print("The image could not be loaded. Please check the path and file permissions.")
# Out:
# Shape: (48, 48, 3)

# %%
import cv2

image_path = r'D:\EMOTION DETECTION\DATASET\test\angry\PrivateTest_88305.JPG'

# Load the image in grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# If the image is loaded successfully, print its pixel values
if img is not None:
    # print(img)
    print("Shape:", img.shape)  # This should now print (48, 48)
else:
    print("The image could not be loaded. Please check the path and file permissions.")
# Out:
# Shape: (48, 48)

# %% [markdown]
# # Model 1 : Custom CNN from Scratch

# %% [markdown]
# ## Initializing the ImageGenerators

# %%
# Define paths to the train and test directories for your local system
train_data_dir = 'D:/EMOTION DETECTION/DATASET/train'
test_data_dir = 'D:/EMOTION DETECTION/DATASET/test'

# %%
# Set some parameters
img_width, img_height = 48, 48  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes

# %%
# Rescale the pixel values (0-255) to the [0, 1] interval
data_generator = ImageDataGenerator(rescale=1./255,
                                    validation_split=0.2)

# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training')

validation_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation')

test_generator = data_generator.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',)
    # subset='validation')
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Accessing class labels for the training data
train_class_labels = train_generator.class_indices
print("Training class labels:", train_class_labels)

# Accessing class labels for the validation data
validation_class_labels = validation_generator.class_indices
print("Validation class labels:", validation_class_labels)

# Accessing class labels for the validation data
test_class_labels = test_generator.class_indices
print("Validation class labels:", test_class_labels)
# Out:
# Training class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Validation class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Validation class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
# Initialising the CNN
model = Sequential()

# Adding convolutional layers with activations on the same line for clarity
model.add(Conv2D(32, kernel_size=(3, 3),kernel_initializer="glorot_uniform", padding='same', input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Conv2D(256, kernel_size=(3, 3), kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening and adding dense layers
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# Out:
# C:\Users\nimis\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  activation_2 (Activation)   (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  activation_3 (Activation)   (None, 22, 22, 256)       0
#
#  batch_normalization_1 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 512)       1180160
#
#  activation_4 (Activation)   (None, 11, 11, 512)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 512)       2359808
#
#  activation_5 (Activation)   (None, 11, 11, 512)       0
#
#  batch_normalization_2 (Bat  (None, 11, 11, 512)       2048
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_6 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 17046535 (65.03 MB)
# Trainable params: 17044871 (65.02 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 22, 22, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 22, 22, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 11, 11, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 11, 11, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 5, 5, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 5, 5, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    13,108,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         7,175 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 7)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,046,535 (65.03 MB)
#  Trainable params: 17,044,871 (65.02 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %%
plot_model(model, to_file = '/content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Architecture.png',
           show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Understanding Callbacks

# %%
# File path for the model checkpoint
cnn_path = 'D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch'
name = 'Custom_CNN_model.keras'
chk_path = os.path.join(cnn_path, name)
chk_path
# Out:
# 'D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\\Custom_CNN_model.keras'

# %%
# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# %%
# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# %%
# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# %%
# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# %%
# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

# %% [markdown]
# # Calculating Steps for epoch

# %%
train_generator.samples
# Out:
# 22968

# %%
train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %% [markdown]
# # Model Training

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_steps_epoch,
    callbacks=callbacks)
# Out:
# Epoch 1/10
# C:\Users\nimis\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.2414 - loss: 13.3816
# Epoch 1: val_loss improved from inf to 13.87367, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 237s 653ms/step - accuracy: 0.2415 - loss: 13.3790 - val_accuracy: 0.1714 - val_loss: 13.8737 - learning_rate: 1.0000e-04
# Epoch 2/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.3352 - loss: 10.7966
# Epoch 2: val_loss improved from 13.87367 to 9.51366, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 216s 601ms/step - accuracy: 0.3353 - loss: 10.7952 - val_accuracy: 0.3923 - val_loss: 9.5137 - learning_rate: 1.0000e-04
# Epoch 3/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.3876 - loss: 8.7604
# Epoch 3: val_loss improved from 9.51366 to 7.45008, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 596ms/step - accuracy: 0.3876 - loss: 8.7591 - val_accuracy: 0.4259 - val_loss: 7.4501 - learning_rate: 1.0000e-04
# Epoch 4/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.4194 - loss: 6.9444
# Epoch 4: val_loss improved from 7.45008 to 5.78399, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 595ms/step - accuracy: 0.4194 - loss: 6.9434 - val_accuracy: 0.4630 - val_loss: 5.7840 - learning_rate: 1.0000e-04
# Epoch 5/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.4555 - loss: 5.4666
# Epoch 5: val_loss improved from 5.78399 to 4.57701, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 245s 683ms/step - accuracy: 0.4555 - loss: 5.4658 - val_accuracy: 0.4830 - val_loss: 4.5770 - learning_rate: 1.0000e-04
# Epoch 6/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4865 - loss: 4.3244
# Epoch 6: val_loss improved from 4.57701 to 3.66028, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 839s 2s/step - accuracy: 0.4865 - loss: 4.3238 - val_accuracy: 0.5079 - val_loss: 3.6603 - learning_rate: 1.0000e-04
# Epoch 7/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5153 - loss: 3.4736
# Epoch 7: val_loss improved from 3.66028 to 3.01964, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 816s 2s/step - accuracy: 0.5153 - loss: 3.4732 - val_accuracy: 0.5191 - val_loss: 3.0196 - learning_rate: 1.0000e-04
# Epoch 8/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5388 - loss: 2.8544
# Epoch 8: val_loss improved from 3.01964 to 2.54849, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 811s 2s/step - accuracy: 0.5388 - loss: 2.8541 - val_accuracy: 0.5440 - val_loss: 2.5485 - learning_rate: 1.0000e-04
# Epoch 9/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5507 - loss: 2.4246
# Epoch 9: val_loss improved from 2.54849 to 2.23903, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 803s 2s/step - accuracy: 0.5508 - loss: 2.4244 - val_accuracy: 0.5471 - val_loss: 2.2390 - learning_rate: 1.0000e-04
# Epoch 10/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5820 - loss: 2.0777
# Epoch 10: val_loss improved from 2.23903 to 2.09266, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 865s 2s/step - accuracy: 0.5820 - loss: 2.0776 - val_accuracy: 0.5320 - val_loss: 2.0927 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# # Plotting Performance Metrics

# %%
def plot_training_history(history):
    """
    Plots the training and validation accuracy and loss.

    Parameters:
    - history: A Keras History object. Contains the logs from the training process.

    Returns:
    - None. Displays the matplotlib plots for training/validation accuracy and loss.
    """
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(20, 5))

    # Plot training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()

# %%
plot_training_history(history)

# %% [markdown]
# # Model Evaluation

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 61s 170ms/step - accuracy: 0.6076 - loss: 1.8822
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 18s 159ms/step - accuracy: 0.5269 - loss: 2.0928
# final train accuracy = 60.59 , validation accuracy = 53.75

# %% [markdown]
# # Plotting Confusion Matrix

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=int(np.ceil(test_generator.samples/test_generator.batch_size))), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 18s 155ms/step

# %%
# Printing the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.14      0.16      0.15       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.15      0.03      0.04      1024
#        happy       0.25      0.28      0.27      1774
#      neutral       0.17      0.30      0.21      1233
#          sad       0.18      0.15      0.16      1247
#     surprise       0.12      0.09      0.10       831
#
#     accuracy                           0.18      7178
#    macro avg       0.14      0.14      0.13      7178
# weighted avg       0.17      0.18      0.17      7178

# %% [markdown]
# # Making Predictions

# %%
# Emotion classes for the dataset
Emotion_Classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Assuming test_generator and model are already defined
batch_size = test_generator.batch_size

# Selecting a random batch from the test generator
Random_batch = np.random.randint(0, len(test_generator) - 1)

# Selecting random image indices from the batch
Random_Img_Index = np.random.randint(0, batch_size, 10)

# Setting up the plot
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(10, 5),
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    # Fetching the random image and its label
    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]
    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]], axis=0)

    # Making a prediction using the model
    Model_Prediction = np.argmax(model.predict(tf.expand_dims(Random_Img, axis=0), verbose=0), axis=1)[0]

    # Displaying the image
    ax.imshow(Random_Img.squeeze(), cmap='gray')  # Assuming the images are grayscale
    # Setting the title with true and predicted labels, colored based on correctness
    color = "green" if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction] else "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model 2: Image Augmentation

# %%
# Define paths to the train and validation directories
train_data_dir = 'D:/EMOTION DETECTION/DATASET/train'
test_data_dir = 'D:/EMOTION DETECTION/DATASET/test'
# validation_data_dir = '/content/emotion_detection_project/datasets/raw/test'

# Set some parameters
img_width, img_height = 48, 48  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes


# Initializing the ImageDataGenerator with data augmentation options for the training set
data_generator = ImageDataGenerator(
    rescale=1./255,  # Rescale the pixel values from [0, 255] to [0, 1]
    rotation_range=40,  # Degree range for random rotations
    width_shift_range=0.2,  # Range (as a fraction of total width) for random horizontal shifts
    height_shift_range=0.2,  # Range (as a fraction of total height) for random vertical shifts
    shear_range=0.2,  # Shearing intensity (shear angle in counter-clockwise direction)
    zoom_range=0.2,  # Range for random zoom
    horizontal_flip=True,  # Randomly flip inputs horizontally
    fill_mode='nearest',  # Strategy to fill newly created pixels, which can appear after a rotation or a width/height shift
    validation_split=0.2  # Set the validation split; 20% of the data will be used for validation
)

test_data_generator = ImageDataGenerator(rescale=1./255)


# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training')

validation_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation')

test_generator = test_data_generator.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
    )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Path to your specific image
image_path = 'D:/EMOTION DETECTION/DATASET/train/angry/Training_1294170.jpg'

# Load and convert the image to an array
img = load_img(image_path, color_mode='grayscale', target_size=(img_width, img_height))  # Adjust color_mode if necessary
img_array = img_to_array(img)  # Converts the image to a numpy array
img_array = img_array.reshape((1,) + img_array.shape)  # Reshapes the image to (1, width, height, channels) for the generator

# Setting up the plot
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(10, 4))
# Plot the original image first. Since img_array is a 3D array after reshaping, we use [:, :, 0]
axes[0].imshow(img_array[0, :, :, 0], cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Generate and plot augmented images
for i, ax in enumerate(axes.flat[1:]):  # Start from the second subplot
    # Generate a batch of augmented images
    aug_iter = data_generator.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0]  # Get the first augmented image from the batch

    # Plot the augmented image. We directly use [:, :, 0] without an initial batch index
    ax.imshow(aug_img[:, :, 0], cmap='gray')
    ax.set_title(f'Augmented Image {i+1}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Same CNN Model as above

# %%
# Assuming img_width, img_height, and classes are defined. For example:
img_width, img_height = 48, 48
classes = 7

#Initialising the CNN
model = tf.keras.models.Sequential()

# Adding convolutional layers with activations on separate lines
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=(img_width, img_height, 1)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(256, kernel_size=(3, 3), kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening and adding dense layers
model.add(Flatten())
model.add(Dense(1024))
model.add(tf.keras.layers.Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(classes))
model.add(tf.keras.layers.Activation('softmax'))

# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# File path for the model checkpoint
cnn_path = r'D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation'
name = 'Custom_CNN_augmented_model.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

history = model.fit(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=validation_steps_epoch,
    callbacks=callbacks)
# Out:
# <>:49: SyntaxWarning: invalid escape sequence '\E'
# <>:49: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\nimis\AppData\Local\Temp\ipykernel_6824\3739076963.py:49: SyntaxWarning: invalid escape sequence '\E'
#   cnn_path = 'D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation'
# C:\Users\nimis\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nimis\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.2032 - loss: 13.4360
# Epoch 1: val_loss improved from inf to 14.47889, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 227s 625ms/step - accuracy: 0.2033 - loss: 13.4335 - val_accuracy: 0.0561 - val_loss: 14.4789 - learning_rate: 1.0000e-04
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.2423 - loss: 10.9053
# Epoch 2: val_loss improved from 14.47889 to 10.06286, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 219s 611ms/step - accuracy: 0.2423 - loss: 10.9038 - val_accuracy: 0.1975 - val_loss: 10.0629 - learning_rate: 1.0000e-04
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.2498 - loss: 8.8018
# Epoch 3: val_loss improved from 10.06286 to 7.55737, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 218s 608ms/step - accuracy: 0.2498 - loss: 8.8004 - val_accuracy: 0.2548 - val_loss: 7.5574 - learning_rate: 1.0000e-04
# Epoch 4/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.2497 - loss: 6.9029
# Epoch 4: val_loss improved from 7.55737 to 5.84125, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 218s 607ms/step - accuracy: 0.2497 - loss: 6.9017 - val_accuracy: 0.2625 - val_loss: 5.8412 - learning_rate: 1.0000e-04
# Epoch 5/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.2608 - loss: 5.3546
# Epoch 5: val_loss improved from 5.84125 to 4.71142, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 219s 610ms/step - accuracy: 0.2608 - loss: 5.3537 - val_accuracy: 0.2656 - val_loss: 4.7114 - learning_rate: 1.0000e-04
# Epoch 6/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.2606 - loss: 4.2060
# Epoch 6: val_loss improved from 4.71142 to 3.60880, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 219s 610ms/step - accuracy: 0.2606 - loss: 4.2053 - val_accuracy: 0.2770 - val_loss: 3.6088 - learning_rate: 1.0000e-04
# Epoch 7/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.2860 - loss: 3.3840
# Epoch 7: val_loss improved from 3.60880 to 2.90790, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 217s 605ms/step - accuracy: 0.2860 - loss: 3.3836 - val_accuracy: 0.3153 - val_loss: 2.9079 - learning_rate: 1.0000e-04
# Epoch 8/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.2902 - loss: 2.8291
# Epoch 8: val_loss improved from 2.90790 to 2.62962, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 218s 607ms/step - accuracy: 0.2902 - loss: 2.8288 - val_accuracy: 0.2949 - val_loss: 2.6296 - learning_rate: 1.0000e-04
# Epoch 9/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.3259 - loss: 2.4288
# Epoch 9: val_loss improved from 2.62962 to 2.23235, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 222s 617ms/step - accuracy: 0.3259 - loss: 2.4286 - val_accuracy: 0.3350 - val_loss: 2.2323 - learning_rate: 1.0000e-04
# Epoch 10/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.3683 - loss: 2.1562
# Epoch 10: val_loss improved from 2.23235 to 2.07220, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 216s 600ms/step - accuracy: 0.3683 - loss: 2.1561 - val_accuracy: 0.3722 - val_loss: 2.0722 - learning_rate: 1.0000e-04
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.4025 - loss: 1.9688
# Epoch 11: val_loss improved from 2.07220 to 1.88025, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 215s 598ms/step - accuracy: 0.4025 - loss: 1.9687 - val_accuracy: 0.4090 - val_loss: 1.8802 - learning_rate: 1.0000e-04
# Epoch 12/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.4196 - loss: 1.8407
# Epoch 12: val_loss improved from 1.88025 to 1.83543, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 215s 599ms/step - accuracy: 0.4197 - loss: 1.8406 - val_accuracy: 0.3895 - val_loss: 1.8354 - learning_rate: 1.0000e-04
# Epoch 13/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.4402 - loss: 1.7457
# Epoch 13: val_loss improved from 1.83543 to 1.73548, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 215s 599ms/step - accuracy: 0.4402 - loss: 1.7457 - val_accuracy: 0.4292 - val_loss: 1.7355 - learning_rate: 1.0000e-04
# Epoch 14/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.4607 - loss: 1.6667
# Epoch 14: val_loss improved from 1.73548 to 1.62926, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 215s 599ms/step - accuracy: 0.4607 - loss: 1.6667 - val_accuracy: 0.4626 - val_loss: 1.6293 - learning_rate: 1.0000e-04
# Epoch 15/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.4820 - loss: 1.5943
# Epoch 15: val_loss improved from 1.62926 to 1.55005, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 215s 599ms/step - accuracy: 0.4820 - loss: 1.5943 - val_accuracy: 0.4905 - val_loss: 1.5501 - learning_rate: 1.0000e-04
# Epoch 16/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.4856 - loss: 1.5548
# Epoch 16: val_loss improved from 1.55005 to 1.50098, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 217s 604ms/step - accuracy: 0.4856 - loss: 1.5548 - val_accuracy: 0.5048 - val_loss: 1.5010 - learning_rate: 1.0000e-04
# Epoch 17/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.5066 - loss: 1.5059
# Epoch 17: val_loss improved from 1.50098 to 1.48143, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 597ms/step - accuracy: 0.5066 - loss: 1.5059 - val_accuracy: 0.5132 - val_loss: 1.4814 - learning_rate: 1.0000e-04
# Epoch 18/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.5152 - loss: 1.4762
# Epoch 18: val_loss improved from 1.48143 to 1.42548, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 216s 600ms/step - accuracy: 0.5152 - loss: 1.4762 - val_accuracy: 0.5304 - val_loss: 1.4255 - learning_rate: 1.0000e-04
# Epoch 19/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.5254 - loss: 1.4483
# Epoch 19: val_loss did not improve from 1.42548
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 215s 600ms/step - accuracy: 0.5254 - loss: 1.4483 - val_accuracy: 0.5006 - val_loss: 1.4653 - learning_rate: 1.0000e-04
# Epoch 20/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.5265 - loss: 1.4294
# Epoch 20: val_loss did not improve from 1.42548
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 596ms/step - accuracy: 0.5265 - loss: 1.4294 - val_accuracy: 0.4903 - val_loss: 1.5081 - learning_rate: 1.0000e-04
# Epoch 21/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.5308 - loss: 1.4192
# Epoch 21: val_loss improved from 1.42548 to 1.37167, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 225s 627ms/step - accuracy: 0.5308 - loss: 1.4192 - val_accuracy: 0.5408 - val_loss: 1.3717 - learning_rate: 1.0000e-04
# Epoch 22/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.5403 - loss: 1.3884
# Epoch 22: val_loss did not improve from 1.37167
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 256s 713ms/step - accuracy: 0.5403 - loss: 1.3884 - val_accuracy: 0.5363 - val_loss: 1.4045 - learning_rate: 1.0000e-04
# Epoch 23/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.5430 - loss: 1.3694
# Epoch 23: val_loss improved from 1.37167 to 1.36710, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 222s 617ms/step - accuracy: 0.5430 - loss: 1.3695 - val_accuracy: 0.5483 - val_loss: 1.3671 - learning_rate: 1.0000e-04
# Epoch 24/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.5439 - loss: 1.3748
# Epoch 24: val_loss did not improve from 1.36710
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 206s 572ms/step - accuracy: 0.5439 - loss: 1.3747 - val_accuracy: 0.5469 - val_loss: 1.3683 - learning_rate: 1.0000e-04
# Epoch 25/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.5595 - loss: 1.3353
# Epoch 25: val_loss improved from 1.36710 to 1.35898, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 206s 573ms/step - accuracy: 0.5595 - loss: 1.3353 - val_accuracy: 0.5455 - val_loss: 1.3590 - learning_rate: 1.0000e-04
# Epoch 26/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.5551 - loss: 1.3438
# Epoch 26: val_loss did not improve from 1.35898
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 212s 592ms/step - accuracy: 0.5551 - loss: 1.3438 - val_accuracy: 0.5442 - val_loss: 1.3659 - learning_rate: 1.0000e-04
# Epoch 27/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.5609 - loss: 1.3091
# Epoch 27: val_loss improved from 1.35898 to 1.34340, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 213s 593ms/step - accuracy: 0.5608 - loss: 1.3091 - val_accuracy: 0.5475 - val_loss: 1.3434 - learning_rate: 1.0000e-04
# Epoch 28/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.5704 - loss: 1.3099
# Epoch 28: val_loss did not improve from 1.34340
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 210s 584ms/step - accuracy: 0.5704 - loss: 1.3099 - val_accuracy: 0.5504 - val_loss: 1.3927 - learning_rate: 1.0000e-04
# Epoch 29/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.5734 - loss: 1.2935
# Epoch 29: val_loss improved from 1.34340 to 1.30728, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 210s 586ms/step - accuracy: 0.5734 - loss: 1.2935 - val_accuracy: 0.5649 - val_loss: 1.3073 - learning_rate: 1.0000e-04
# Epoch 30/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.5717 - loss: 1.3044
# Epoch 30: val_loss did not improve from 1.30728
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 213s 595ms/step - accuracy: 0.5717 - loss: 1.3044 - val_accuracy: 0.5684 - val_loss: 1.3094 - learning_rate: 1.0000e-04
# Epoch 31/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.5713 - loss: 1.2958
# Epoch 31: val_loss did not improve from 1.30728
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 595ms/step - accuracy: 0.5713 - loss: 1.2958 - val_accuracy: 0.5548 - val_loss: 1.3284 - learning_rate: 1.0000e-04
# Epoch 32/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.5839 - loss: 1.2820
# Epoch 32: val_loss improved from 1.30728 to 1.30251, saving model to D:\EMOTION DETECTION\FER_2013_Emotion_Detection\Custom_CNN_With_Augmentation\Custom_CNN_augmented_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 596ms/step - accuracy: 0.5839 - loss: 1.2820 - val_accuracy: 0.5617 - val_loss: 1.3025 - learning_rate: 1.0000e-04
# Epoch 33/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.5789 - loss: 1.2785
# Epoch 33: val_loss did not improve from 1.30251
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 598ms/step - accuracy: 0.5789 - loss: 1.2785 - val_accuracy: 0.5598 - val_loss: 1.3045 - learning_rate: 1.0000e-04
# Epoch 34/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.5783 - loss: 1.2726
# Epoch 34: val_loss did not improve from 1.30251
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 214s 596ms/step - accuracy: 0.5783 - loss: 1.2726 - val_accuracy: 0.5377 - val_loss: 1.4228 - learning_rate: 1.0000e-04
# Epoch 35/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.5878 - loss: 1.2652
# Epoch 35: val_loss did not improve from 1.30251
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 212s 592ms/step - accuracy: 0.5878 - loss: 1.2652 - val_accuracy: 0.5717 - val_loss: 1.3096 - learning_rate: 1.0000e-04
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %%
plot_training_history(history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 57s 158ms/step - accuracy: 0.5825 - loss: 1.2438
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 18s 160ms/step - accuracy: 0.5945 - loss: 1.2389
# final train accuracy = 58.48 , validation accuracy = 59.85

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=int(np.ceil(test_generator.samples/test_generator.batch_size))), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 139ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.12      0.15      0.14       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.14      0.11      0.12      1024
#        happy       0.24      0.23      0.24      1774
#      neutral       0.18      0.13      0.15      1233
#          sad       0.17      0.24      0.20      1247
#     surprise       0.10      0.09      0.10       831
#
#     accuracy                           0.17      7178
#    macro avg       0.14      0.14      0.13      7178
# weighted avg       0.17      0.17      0.17      7178

# %% [markdown]
# # Model 3: Transfer Learning VGGNET

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define paths to the train and validation directories
train_data_dir = '/content/train'
test_data_dir = '/content/test'

# validation_data_dir = '/content/emotion_detection_project/datasets/raw/test'

# Set some parameters
img_width, img_height = 224, 224  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes

# Rescale the pixel values (0-255) to the [0, 1] interval
data_generator = ImageDataGenerator(
                                rescale = 1 / 255.,
                                rotation_range=10,
                                zoom_range=0.2,
                                width_shift_range=0.1,
                                height_shift_range=0.1,
                                horizontal_flip=True,
                                fill_mode='nearest',
                                # validation_split=0.2
                                )

test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
                                train_data_dir,
                                target_size=(img_width, img_height),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',
                                subset='training',
                                shuffle = True)

test_generator = test_preprocessor.flow_from_directory(
                                test_data_dir,
                                target_size=(img_width, img_height),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',)
                                # subset='validation')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Extract class labels for all instances in the training dataset
classes = np.array(train_generator.classes)

# Calculate class weights to handle imbalances in the training data
# 'balanced' mode automatically adjusts weights inversely proportional to class frequencies
class_weights = compute_class_weight(
    class_weight='balanced',  # Strategy to balance classes
    classes=np.unique(classes),  # Unique class labels
    y=classes  # Class labels for each instance in the training dataset
)

# Create a dictionary mapping class indices to their calculated weights
class_weights_dict = dict(enumerate(class_weights))

# Output the class weights dictionary
print("Class Weights Dictionary:", class_weights_dict)
# Out:
# Class Weights Dictionary: {0: 1.0266046844269623, 1: 9.406618610747051, 2: 1.0010460615781582, 3: 0.5684387684387684, 4: 0.8260394187886635, 5: 0.8491274770777877, 6: 1.293372978330405}

# %%
classes = 7

# Clear the previous TensorFlow sessionx
tf.keras.backend.clear_session()

# Load the VGG16 base model, excluding its top (fully connected) layers
vgg = VGG16(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Make the specified layers non-trainable
for layer in vgg.layers[:-3]:
    layer.trainable = False

vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 4719616 (18.00 MB)
# Non-trainable params: 9995072 (38.13 MB)
# _________________________________________________________________

# %%
classes
# Out:
# array([0, 0, 0, ..., 6, 6, 6], dtype=int32)

# %%
# Flattening the layer and adding custom Dense layers
x = Flatten()(vgg.output)

# Adding a fully connected layer with ReLU activation and He normal initializer
x = Dense(1024, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)  # Adding dropout for regularization

x = Dense(512, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)  # Adding dropout for regularization

# Adding the output layer with softmax activation
# Note: Adjust the number of units to match the number of classes you have
output = Dense(7, activation='softmax', kernel_initializer='he_normal')(x)

# Creating the model
model = Model(inputs=vgg.input, outputs=output)

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False),
              metrics=['accuracy'])

# Model summary to see all layers
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 1024)              25691136
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 40934215 (156.15 MB)
# Trainable params: 30939143 (118.02 MB)
# Non-trainable params: 9995072 (38.13 MB)
# _________________________________________________________________

# %%
# File path for the model checkpoint
cnn_path = '/content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning'
name = 'VGG16_Transfer_Learning.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
# validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %%
history = model.fit(
                    train_generator,
                    steps_per_epoch=train_steps_per_epoch,
                    epochs=50,
                    validation_data=test_generator,
                    validation_steps=test_steps_epoch,
                    class_weight=class_weights_dict,
                    callbacks = callbacks
                    )
# Out:
# Epoch 1/50
# 449/449 [==============================] - ETA: 0s - loss: 1.8374 - accuracy: 0.2601
# Epoch 1: val_loss improved from inf to 1.47277, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 436s 933ms/step - loss: 1.8374 - accuracy: 0.2601 - val_loss: 1.4728 - val_accuracy: 0.4401 - lr: 1.0000e-04
# Epoch 2/50
# 449/449 [==============================] - ETA: 0s - loss: 1.6075 - accuracy: 0.3841
# Epoch 2: val_loss improved from 1.47277 to 1.39369, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 433s 963ms/step - loss: 1.6075 - accuracy: 0.3841 - val_loss: 1.3937 - val_accuracy: 0.4698 - lr: 1.0000e-04
# Epoch 3/50
# 449/449 [==============================] - ETA: 0s - loss: 1.4904 - accuracy: 0.4273
# Epoch 3: val_loss did not improve from 1.39369
# 449/449 [==============================] - 419s 934ms/step - loss: 1.4904 - accuracy: 0.4273 - val_loss: 1.4036 - val_accuracy: 0.4588 - lr: 1.0000e-04
# Epoch 4/50
# 449/449 [==============================] - ETA: 0s - loss: 1.4194 - accuracy: 0.4539
# Epoch 4: val_loss improved from 1.39369 to 1.37222, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 431s 959ms/step - loss: 1.4194 - accuracy: 0.4539 - val_loss: 1.3722 - val_accuracy: 0.4780 - lr: 1.0000e-04
# Epoch 5/50
# 449/449 [==============================] - ETA: 0s - loss: 1.3552 - accuracy: 0.4765
# Epoch 5: val_loss improved from 1.37222 to 1.32786, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 434s 966ms/step - loss: 1.3552 - accuracy: 0.4765 - val_loss: 1.3279 - val_accuracy: 0.4921 - lr: 1.0000e-04
# Epoch 6/50
# 449/449 [==============================] - ETA: 0s - loss: 1.3060 - accuracy: 0.4932
# Epoch 6: val_loss improved from 1.32786 to 1.22642, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 424s 944ms/step - loss: 1.3060 - accuracy: 0.4932 - val_loss: 1.2264 - val_accuracy: 0.5301 - lr: 1.0000e-04
# Epoch 7/50
# 449/449 [==============================] - ETA: 0s - loss: 1.2656 - accuracy: 0.5088
# Epoch 7: val_loss improved from 1.22642 to 1.20169, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 434s 966ms/step - loss: 1.2656 - accuracy: 0.5088 - val_loss: 1.2017 - val_accuracy: 0.5401 - lr: 1.0000e-04
# Epoch 8/50
# 449/449 [==============================] - ETA: 0s - loss: 1.2326 - accuracy: 0.5152
# Epoch 8: val_loss improved from 1.20169 to 1.15415, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 432s 961ms/step - loss: 1.2326 - accuracy: 0.5152 - val_loss: 1.1542 - val_accuracy: 0.5500 - lr: 1.0000e-04
# Epoch 9/50
# 449/449 [==============================] - ETA: 0s - loss: 1.2030 - accuracy: 0.5319
# Epoch 9: val_loss did not improve from 1.15415
# 449/449 [==============================] - 441s 982ms/step - loss: 1.2030 - accuracy: 0.5319 - val_loss: 1.1635 - val_accuracy: 0.5581 - lr: 1.0000e-04
# Epoch 10/50
# 449/449 [==============================] - ETA: 0s - loss: 1.1703 - accuracy: 0.5375
# Epoch 10: val_loss did not improve from 1.15415
# 449/449 [==============================] - 423s 941ms/step - loss: 1.1703 - accuracy: 0.5375 - val_loss: 1.1734 - val_accuracy: 0.5520 - lr: 1.0000e-04
# Epoch 11/50
# 449/449 [==============================] - ETA: 0s - loss: 1.1469 - accuracy: 0.5472
# Epoch 11: val_loss did not improve from 1.15415
# Restoring model weights from the end of the best epoch: 8.
# 449/449 [==============================] - 425s 946ms/step - loss: 1.1469 - accuracy: 0.5472 - val_loss: 1.1745 - val_accuracy: 0.5550 - lr: 1.0000e-04
# Epoch 11: early stopping

# %%
plot_training_history(history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 401s 893ms/step - loss: 1.1518 - accuracy: 0.5593
# 113/113 [==============================] - 29s 257ms/step - loss: 1.1542 - accuracy: 0.5500
# final train accuracy = 55.93 , validation accuracy = 55.00

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 28s 250ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.15      0.14      0.14       958
#      disgust       0.02      0.04      0.02       111
#         fear       0.13      0.06      0.08      1024
#        happy       0.25      0.29      0.27      1774
#      neutral       0.17      0.24      0.20      1233
#          sad       0.17      0.11      0.13      1247
#     surprise       0.12      0.13      0.12       831
#
#     accuracy                           0.17      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.17      0.17      0.17      7178

# %% [markdown]
# # Model 4 : Transfer Leanring - ResNet50

# %%
# Directory paths for training and testing data
train_dir = 'D:/EMOTION DETECTION/DATASET/train'
test_dir = 'D:/EMOTION DETECTION/DATASET/test'

# Batch size for data generators
batch_size = 64

# Data augmentation configuration for training data
train_datagen = ImageDataGenerator(
                                  rescale=1 / 255.,  # Rescale pixel values to [0,1]
                                  rotation_range=10,  # Random rotation within range [-10,10] degrees
                                  zoom_range=0.2,  # Random zoom between [0.8, 1.2]
                                  width_shift_range=0.1,  # Random horizontal shift within range [-0.1, 0.1]
                                  height_shift_range=0.1,  # Random vertical shift within range [-0.1, 0.1]
                                  horizontal_flip=True,  # Random horizontal flip
                                  fill_mode='nearest'  # Fill mode for handling newly created pixels
                                 )

# Configuration for testing data (only rescaling)
test_datagen = ImageDataGenerator(
                                  rescale=1 / 255.  # Rescale pixel values to [0,1]
                                 )

# Data generators for training and testing data
train_generator = train_datagen.flow_from_directory(
                                                    train_dir,  # Directory containing training data
                                                    class_mode="categorical",  # Classification mode for categorical labels
                                                    target_size=(224, 224),  # Resize input images to (224,224)
                                                    color_mode='rgb',  # Color mode for images (RGB)
                                                    shuffle=True,  # Shuffle training data
                                                    batch_size=batch_size,  # Batch size for training
                                                    subset='training'  # Subset of data (training)
                                                   )

test_generator = test_datagen.flow_from_directory(
                                                  test_dir,  # Directory containing testing data
                                                  class_mode="categorical",  # Classification mode for categorical labels
                                                  target_size=(224, 224),  # Resize input images to (224,224)
                                                  color_mode="rgb",  # Color mode for images (RGB)
                                                  shuffle=False,  # Do not shuffle testing data
                                                  batch_size=batch_size  # Batch size for testing
                                                 )
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Introducing Class wieghts for imbalanced data

# %%
# Extract class labels for all instances in the training dataset
classes = np.array(train_generator.classes)

# Calculate class weights to handle imbalances in the training data
# 'balanced' mode automatically adjusts weights inversely proportional to class frequencies
class_weights = compute_class_weight(
    class_weight='balanced',  # Strategy to balance classes
    classes=np.unique(classes),  # Unique class labels
    y=classes  # Class labels for each instance in the training dataset
)

# Create a dictionary mapping class indices to their calculated weights
class_weights_dict = dict(enumerate(class_weights))

# Output the class weights dictionary
print("Class Weights Dictionary:", class_weights_dict)
# Out:
# Class Weights Dictionary: {0: 1.0266046844269623, 1: 9.406618610747051, 2: 1.0010460615781582, 3: 0.5684387684387684, 4: 0.8260394187886635, 5: 0.8491274770777877, 6: 1.293372978330405}

# %%
ResNet50V2 = tf.keras.applications.ResNet50V2(input_shape=(224, 224, 3),
                                               include_top= False,
                                               weights='imagenet'
                                               )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
# Freezing all layers except last 50

ResNet50V2.trainable = True

for layer in ResNet50V2.layers[:-50]:
    layer.trainable = False

# %%
def Create_ResNet50V2_Model():

    model = Sequential([
                      ResNet50V2,
                      Dropout(0.25),
                      BatchNormalization(),
                      Flatten(),
                      Dense(64, activation='relu'),
                      BatchNormalization(),
                      Dropout(0.5),
                      Dense(7,activation='softmax')
                    ])
    return model

# %%
model = Create_ResNet50V2_Model()
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)         │ (None, 7, 7, 2048)     │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 7, 7, 2048)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 7, 7, 2048)     │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │     6,422,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,996,295 (114.43 MB)
#  Trainable params: 22,779,527 (86.90 MB)
#  Non-trainable params: 7,216,768 (27.53 MB)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# File path for the model checkpoint
cnn_path = 'D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning'
name = 'ResNet50_Transfer_Learning.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor = 'val_accuracy',
                          patience = 7,
                          restore_best_weights = True,
                          verbose=1)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=2,
#                             min_lr=0.00005,
                              verbose=1)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
# validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %%
train_history = model.fit(
                          train_generator,
                          steps_per_epoch=train_steps_per_epoch,
                          epochs=30,
                          validation_data=test_generator,
                          validation_steps=test_steps_epoch,
                          class_weight=class_weights_dict,
                          callbacks = callbacks
                         )
# Out:
# C:\Users\nimis\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3398 - loss: 1.8932
# Epoch 1: val_loss improved from inf to 5.81486, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 953s 2s/step - accuracy: 0.3399 - loss: 1.8927 - val_accuracy: 0.4046 - val_loss: 5.8149
# Epoch 2/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4663 - loss: 1.4386
# Epoch 2: val_loss improved from 5.81486 to 2.94810, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 918s 2s/step - accuracy: 0.4662 - loss: 1.4388 - val_accuracy: 0.4260 - val_loss: 2.9481
# Epoch 3/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4885 - loss: 1.4111
# Epoch 3: val_loss improved from 2.94810 to 1.19522, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 919s 2s/step - accuracy: 0.4885 - loss: 1.4110 - val_accuracy: 0.5535 - val_loss: 1.1952
# Epoch 4/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5359 - loss: 1.2678
# Epoch 4: val_loss did not improve from 1.19522
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 883s 2s/step - accuracy: 0.5359 - loss: 1.2677 - val_accuracy: 0.5578 - val_loss: 1.2807
# Epoch 5/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5618 - loss: 1.1616
# Epoch 5: val_loss did not improve from 1.19522
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1104s 2s/step - accuracy: 0.5618 - loss: 1.1616 - val_accuracy: 0.5531 - val_loss: 1.2244
# Epoch 6/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5625 - loss: 1.1730
# Epoch 6: val_loss did not improve from 1.19522
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 875s 2s/step - accuracy: 0.5625 - loss: 1.1730 - val_accuracy: 0.5262 - val_loss: 1.3294
# Epoch 7/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5597 - loss: 1.1657
# Epoch 7: val_loss improved from 1.19522 to 1.07529, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 845s 2s/step - accuracy: 0.5597 - loss: 1.1657 - val_accuracy: 0.6010 - val_loss: 1.0753
# Epoch 8/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5847 - loss: 1.1103
# Epoch 8: val_loss improved from 1.07529 to 1.04020, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 835s 2s/step - accuracy: 0.5848 - loss: 1.1103 - val_accuracy: 0.6169 - val_loss: 1.0402
# Epoch 9/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6011 - loss: 1.0521
# Epoch 9: val_loss did not improve from 1.04020
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 823s 2s/step - accuracy: 0.6011 - loss: 1.0521 - val_accuracy: 0.6002 - val_loss: 1.0732
# Epoch 10/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6128 - loss: 1.0319
# Epoch 10: val_loss did not improve from 1.04020
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 827s 2s/step - accuracy: 0.6128 - loss: 1.0319 - val_accuracy: 0.6176 - val_loss: 1.0708
# Epoch 11/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6146 - loss: 1.0086
# Epoch 11: val_loss improved from 1.04020 to 1.01838, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 823s 2s/step - accuracy: 0.6146 - loss: 1.0086 - val_accuracy: 0.6278 - val_loss: 1.0184
# Epoch 12/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6199 - loss: 0.9967
# Epoch 12: val_loss did not improve from 1.01838
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 851s 2s/step - accuracy: 0.6199 - loss: 0.9968 - val_accuracy: 0.6232 - val_loss: 1.0308
# Epoch 13/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6219 - loss: 0.9851
# Epoch 13: val_loss did not improve from 1.01838
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 841s 2s/step - accuracy: 0.6219 - loss: 0.9851 - val_accuracy: 0.5988 - val_loss: 1.1409
# Epoch 14/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6296 - loss: 0.9591
# Epoch 14: val_loss did not improve from 1.01838
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 896s 2s/step - accuracy: 0.6296 - loss: 0.9591 - val_accuracy: 0.6244 - val_loss: 1.0286
# Epoch 15/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6369 - loss: 0.9361
# Epoch 15: val_loss improved from 1.01838 to 1.00901, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 860s 2s/step - accuracy: 0.6369 - loss: 0.9361 - val_accuracy: 0.6215 - val_loss: 1.0090
# Epoch 16/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6518 - loss: 0.9118
# Epoch 16: val_loss did not improve from 1.00901
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 852s 2s/step - accuracy: 0.6518 - loss: 0.9119 - val_accuracy: 0.6063 - val_loss: 1.0813
# Epoch 17/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6418 - loss: 0.9251
# Epoch 17: val_loss improved from 1.00901 to 0.98523, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 853s 2s/step - accuracy: 0.6418 - loss: 0.9251 - val_accuracy: 0.6337 - val_loss: 0.9852
# Epoch 18/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6521 - loss: 0.9155
# Epoch 18: val_loss did not improve from 0.98523
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 854s 2s/step - accuracy: 0.6521 - loss: 0.9155 - val_accuracy: 0.6149 - val_loss: 1.0630
# Epoch 19/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6604 - loss: 0.8691
# Epoch 19: val_loss improved from 0.98523 to 0.95457, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 860s 2s/step - accuracy: 0.6604 - loss: 0.8691 - val_accuracy: 0.6516 - val_loss: 0.9546
# Epoch 20/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6708 - loss: 0.8482
# Epoch 20: val_loss did not improve from 0.95457
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 868s 2s/step - accuracy: 0.6708 - loss: 0.8483 - val_accuracy: 0.6466 - val_loss: 0.9901
# Epoch 21/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6631 - loss: 0.8652
# Epoch 21: val_loss did not improve from 0.95457
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 852s 2s/step - accuracy: 0.6631 - loss: 0.8652 - val_accuracy: 0.6351 - val_loss: 1.0152
# Epoch 22/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6694 - loss: 0.8481
# Epoch 22: val_loss did not improve from 0.95457
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 852s 2s/step - accuracy: 0.6694 - loss: 0.8481 - val_accuracy: 0.6505 - val_loss: 0.9616
# Epoch 23/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6809 - loss: 0.8233
# Epoch 23: val_loss did not improve from 0.95457
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 855s 2s/step - accuracy: 0.6809 - loss: 0.8233 - val_accuracy: 0.6358 - val_loss: 0.9993
# Epoch 24/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6828 - loss: 0.8145
# Epoch 24: val_loss improved from 0.95457 to 0.94732, saving model to D:/EMOTION DETECTION/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 857s 2s/step - accuracy: 0.6828 - loss: 0.8145 - val_accuracy: 0.6556 - val_loss: 0.9473
# Epoch 25/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6912 - loss: 0.7829
# Epoch 25: val_loss did not improve from 0.94732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 853s 2s/step - accuracy: 0.6912 - loss: 0.7830 - val_accuracy: 0.6435 - val_loss: 1.0196
# Epoch 26/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6826 - loss: 0.7978
# Epoch 26: val_loss did not improve from 0.94732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 851s 2s/step - accuracy: 0.6826 - loss: 0.7978 - val_accuracy: 0.6354 - val_loss: 1.0685
# Epoch 27/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6922 - loss: 0.7867
# Epoch 27: val_loss did not improve from 0.94732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 855s 2s/step - accuracy: 0.6922 - loss: 0.7867 - val_accuracy: 0.6470 - val_loss: 0.9855
# Epoch 28/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6991 - loss: 0.7777
# Epoch 28: val_loss did not improve from 0.94732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 855s 2s/step - accuracy: 0.6991 - loss: 0.7777 - val_accuracy: 0.6510 - val_loss: 0.9902
# Epoch 29/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7070 - loss: 0.7461
# Epoch 29: val_loss did not improve from 0.94732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 852s 2s/step - accuracy: 0.7069 - loss: 0.7461 - val_accuracy: 0.6535 - val_loss: 0.9811
# Epoch 30/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7085 - loss: 0.7420
# Epoch 30: val_loss did not improve from 0.94732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 851s 2s/step - accuracy: 0.7085 - loss: 0.7420 - val_accuracy: 0.6488 - val_loss: 0.9898
# Restoring model weights from the end of the best epoch: 24.

# %%
plot_training_history(train_history)

# %%
import keras

# %%
# model = keras.saving.load_model("/content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras")

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 465s 1s/step - accuracy: 0.7145 - loss: 0.7720
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 107s 943ms/step - accuracy: 0.6316 - loss: 0.9973
# final train accuracy = 71.29 , validation accuracy = 65.56

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=int(np.ceil(test_generator.samples/test_generator.batch_size))), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 110s 964ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.54      0.66      0.59       958
#      disgust       0.61      0.66      0.63       111
#         fear       0.58      0.33      0.42      1024
#        happy       0.85      0.87      0.86      1774
#      neutral       0.59      0.63      0.61      1233
#          sad       0.52      0.56      0.54      1247
#     surprise       0.77      0.77      0.77       831
#
#     accuracy                           0.66      7178
#    macro avg       0.64      0.64      0.63      7178
# weighted avg       0.66      0.66      0.65      7178

# %% [markdown]
# # AUC ROC plot for each class

# %%
true_labels = test_generator.classes
preds = model.predict(test_generator, steps=len(test_generator))
pred_labels = np.argmax(preds, axis=1)
classes=list(test_generator.class_indices.keys())
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 112s 989ms/step

# %%
y_encoded = pd.get_dummies(true_labels).astype(int).values
preds_encoded = pd.get_dummies(pred_labels).astype(int).values

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_encoded[:,i], preds_encoded[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10,5))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']
for i, color in enumerate(colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f"ROC curve for {classes[i]} (area = {roc_auc[i]:0.2f})")

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# %%
model.save("Resnet_model_version_2.keras")

# %% [markdown]
# # Push all your models into Drive for easy access.

# %%
# !cp /content/FER_2013_Emotion_Detection /content/drive/MyDrive/

# %% [markdown]
# ## If you are here and followed and learned everything, you are in a great positon to build a project at a industry standard level. Kudos to you!!
# ## All that's left is Deployement

# %% [markdown]
# # Deployement

# %% [markdown]
# # Gradio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gradio
#   Downloading gradio-5.28.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.10.0 (from gradio)
#   Downloading gradio_client-1.10.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\programdata\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub>=0.28.1 (from gradio)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.11.7-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.15.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from gradio-client==1.10.0->gradio) (2024.6.1)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.10.0->gradio)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-5.28.0-py3-none-any.whl (54.1 MB)
#    ---------------------------------------- 0.0/54.1 MB ? eta -:--:--
#    - -------------------------------------- 2.1/54.1 MB 14.7 MB/s eta 0:00:04
#    ------- -------------------------------- 9.7/54.1 MB 27.4 MB/s eta 0:00:02
#    ------------ --------------------------- 16.5/54.1 MB 32.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 22.0/54.1 MB 28.4 MB/s eta 0:00:02
#    --------------------- ------------------ 29.4/54.1 MB 29.1 MB/s eta 0:00:01
#    --------------------------- ------------ 37.5/54.1 MB 31.3 MB/s eta 0:00:01
#    --------------------------------- ------ 45.4/54.1 MB 32.1 MB/s eta 0:00:01
#    -------------------------------------- - 52.7/54.1 MB 32.3 MB/s eta 0:00:01
#    ---------------------------------------- 54.1/54.1 MB 31.3 MB/s eta 0:00:00
# Downloading gradio_client-1.10.0-py3-none-any.whl (322 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl (134 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.7-py3-none-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------- ----------------------------- 3.1/11.6 MB 13.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.6 MB 21.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 20.7 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading typer-0.15.3-py3-none-any.whl (45 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Installing collected packages: pydub, websockets, tomlkit, shellingham, semantic-version, ruff, python-multipart, orjson, groovy, ffmpy, aiofiles, uvicorn, starlette, huggingface-hub, typer, safehttpx, gradio-client, fastapi, gradio
# Successfully installed aiofiles-24.1.0 fastapi-0.115.12 ffmpy-0.5.0 gradio-5.28.0 gradio-client-1.10.0 groovy-0.1.2 huggingface-hub-0.30.2 orjson-3.10.18 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.7 safehttpx-0.1.6 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.46.2 tomlkit-0.13.2 typer-0.15.3 uvicorn-0.34.2 websockets-15.0.1
#   WARNING: The script websockets.exe is installed in 'C:\Users\nimis\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'C:\Users\nimis\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli.exe is installed in 'C:\Users\nimis\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'C:\Users\nimis\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fastapi.exe is installed in 'C:\Users\nimis\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts gradio.exe and upload_theme.exe are installed in 'C:\Users\nimis\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import gradio as gr
import gradio as gr
import tensorflow as tf
import numpy as np
from PIL import Image
import cv2
from tensorflow.keras.preprocessing import image

# %%
# Ensure your model is loaded here
# model = ... # Load your trained model
# Load your pre-trained model
model = tf.keras.models.load_model(r'D:\EMOTION DETECTION\FER_2013_Emotion_Detection\ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras')

# %%
# Emotion labels dictionary
emotion_labels = {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
index_to_emotion = {v: k for k, v in emotion_labels.items()}
index_to_emotion
# Out:
# {0: 'angry',
#  1: 'disgust',
#  2: 'fear',
#  3: 'happy',
#  4: 'neutral',
#  5: 'sad',
#  6: 'surprise'}

# %%
def prepare_image(img_pil):
    """Preprocess the PIL image to fit your model's input requirements."""
    # Convert the PIL image to a numpy array with the target size
    img = img_pil.resize((224, 224))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Convert single image to a batch.
    img_array /= 255.0  # Rescale pixel values to [0,1], as done during training
    return img_array



# Define the Gradio interface
def predict_emotion(image):
    # Preprocess the image
    processed_image = prepare_image(image)
    # Make prediction using the model
    prediction = model.predict(processed_image)
    # Get the emotion label with the highest probability
    predicted_class = np.argmax(prediction, axis=1)
    predicted_emotion = index_to_emotion.get(predicted_class[0], "Unknown Emotion")
    return predicted_emotion

interface = gr.Interface(
    fn=predict_emotion,  # Your prediction function
    inputs=gr.Image(type="pil"),  # Input for uploading an image, directly compatible with PIL images
    outputs="text",  # Output as text displaying the predicted emotion
    title="Emotion Detection",
    description="Upload an image and see the predicted emotion."
)

# Launch the Gradio interface
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
